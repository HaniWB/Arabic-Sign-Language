# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd yolov5
# Out:
# c:\Users\hanib\Downloads\deep learning\yolov5
# C:\Users\hanib\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:417: UserWarning: This is now an optional IPython functionality, setting dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !pip install -qr requirements.txt

# %%
import torch
from IPython.display import Image, clear_output

print('setup complete , Using torch %%')
# Out:
# setup complete , Using torch %%

# %%
# !type "C:\Users\hanib\Downloads\Arabic sign language translator.v3i.yolov5pytorch\data.yaml"
# Out:
# train: ../train/images
# test: ../test/images
#
# nc: 13
# names: ['Dog', 'Hello', 'No', 'Thanks', 'fine', 'love', 'me', 'mother', 'smile', 'sorry', 'sunday', 'yes', 'you']

# %%
# %pip install pyyaml

import yaml

with open("C:\\Users\\hanib\\Downloads\\Arabic sign language translator.v3i.yolov5pytorch\\data.yaml" , 'r') as f:
    num_classes = str(yaml.safe_load(f)['nc'])
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
num_classes
# Out:
# '13'

# %%
import sys, torch
print(sys.executable)
print(torch.__version__)
print(torch.version.cuda)
print(torch.cuda.is_available())
# Out:
# c:\Users\hanib\AppData\Local\Programs\Python\Python310\python.exe
# 2.11.0+cu128
# 12.8
# True

# %%
# customize ipython witefile so we can write variables
from IPython.core.magic import register_line_magic
@register_line_magic
def writetemplate(line , cell):
    with open(line, 'w') as f:
        f.write(cell.format(**globals()))

# %%
import os
os.makedirs('/content/yolov5/models', exist_ok=True)

# %%
# %cd "C:/Users/hanib/Downloads/deep learning"
# Out:
# C:\Users\hanib\Downloads\deep learning

# %%
# %%writefile yolov5/models/custom_yolov5s.yaml
# # parameters
# nc: 13  # change to your number of classes
# depth_multiple: 0.33
# width_multiple: 0.50
# anchors:
#   - [10, 13, 16, 30, 33, 23]
#   - [30, 61, 62, 45, 59, 119]
#   - [116, 90, 156, 198, 373, 326]
# backbone:
#   [
#     [-1, 1, Conv, [64, 6, 2, 2]],
#     [-1, 1, Conv, [128, 3, 2]],
#     [-1, 3, C3, [128]],
#     [-1, 1, Conv, [256, 3, 2]],
#     [-1, 6, C3, [256]],
#     [-1, 1, Conv, [512, 3, 2]],
#     [-1, 9, C3, [512]],
#     [-1, 1, Conv, [1024, 3, 2]],
#     [-1, 3, C3, [1024]],
#     [-1, 1, SPPF, [1024, 5]],
#   ]
# head: [
#     [-1, 1, Conv, [512, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, "nearest"]],
#     [[-1, 6], 1, Concat, [1]],
#     [-1, 3, C3, [512, False]],
#     [-1, 1, Conv, [256, 1, 1]],
#     [-1, 1, nn.Upsample, [None, 2, "nearest"]],
#     [[-1, 4], 1, Concat, [1]],
#     [-1, 3, C3, [256, False]],
#     [-1, 1, Conv
# Out:
# Overwriting yolov5/models/custom_yolov5s.yaml

# %%
# start tesnorboard
# %load_ext tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir runs
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
# Reusing TensorBoard on port 6007 (pid 41344), started 0:04:29 ago. (Use '!kill 41344' to kill it.)
#       <iframe id="tensorboard-frame-d7c5ac442c53d766" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d7c5ac442c53d766");
#           const url = new URL("http://localhost");
#           const port = 6007;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
# !taskkill /PID 41344 /F
# %reload_ext tensorboard
# %tensorboard --logdir yolov5/runs/train
# Out:
# ERROR: The process "41344" not found.
# Reusing TensorBoard on port 6006 (pid 38632), started 0:00:31 ago. (Use '!kill 38632' to kill it.)
#       <iframe id="tensorboard-frame-21dfab3e1abad6af" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-21dfab3e1abad6af");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
from IPython.display import Image, display
display(Image(filename='yolov5/runs/train/exp14/results.png'))

# %%
print('group truth training data')
display(Image(filename='C:\\Users\\hanib\\Downloads\\deep learning\\yolov5\\runs\\train\\exp14\\val_batch0_labels.jpg', width=600))
# Out:
# group truth training data

# %%
print('group truth training data')
display(Image(filename='C:\\Users\\hanib\\Downloads\\deep learning\\yolov5\\runs\\train\\exp14\\train_batch0.jpg', width=600))
# Out:
# group truth training data

# %%
# %cd yolov5
# !python detect.py --weights runs/train/exp14/weights/best.pt --img 640 --conf 0.25 --source "C:\\Users\\hanib\\Downloads\\Arabic sign language translator.v3i.yolov5pytorch\\train\\images"
# Out:
# [WinError 2] The system cannot find the file specified: 'yolov5'
# c:\Users\hanib\Downloads\deep learning\yolov5
# C:\Users\hanib\AppData\Roaming\Python\Python310\site-packages\IPython\core\magics\osm.py:393: UserWarning: This is now an optional IPython functionality, using bookmarks requires you to install the `pickleshare` library.
#   bkms = self.shell.db.get('bookmarks', {})
# detect: weights=['runs/train/exp14/weights/best.pt'], source=C:\\Users\\hanib\\Downloads\\Arabic sign language translator.v3i.yolov5pytorch\\train\\images, data=data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# ...
